# %%
from datasets import load_dataset
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# e:\Machine Learning\hugging_face_transfer_learning.ipynb Cell 1 line 1
# ----> <a href='vscode-notebook-cell:/e%3A/Machine%20Learning/hugging_face_transfer_learning.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> from datasets import load_dataset
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\datasets\__init__.py:22
#       1 # flake8: noqa
#       2 # Copyright 2020 The HuggingFace Datasets Authors and the TensorFlow Datasets Authors.
#       3 #
#    (...)
#      17 # pylint: enable=line-too-long
#      18 # pylint: disable=g-import-not-at-top,g-bad-import-order,wrong-import-position
#      20 __version__ = "2.14.5"
# ---> 22 from .arrow_dataset import Dataset
#      23 from .arrow_reader import ReadInstruction
# ...
